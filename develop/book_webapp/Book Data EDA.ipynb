# %%
import csv
import pandas as pd
import numpy as np
import scipy
import os
import sklearn

# %%
pwd
# Out:
# '/Users/veronicahsieh/Documents/GitHub/MSIA-webapp'

# %%
url = 'https://www.googleapis.com/books/v1/volumes?q=isbn:'

# %%
books = pd.read_csv("/Users/veronicahsieh/Documents/GitHub/MSIA-webapp/goodbooks-10k/books.csv")
ratings = pd.read_csv("/Users/veronicahsieh/Documents/GitHub/MSIA-webapp/goodbooks-10k/ratings.csv")
book_tags = pd.read_csv("/Users/veronicahsieh/Documents/GitHub/MSIA-webapp/goodbooks-10k/book_tags.csv")
tags = pd.read_csv("/Users/veronicahsieh/Documents/GitHub/MSIA-webapp/goodbooks-10k/tags.csv")

# %%
books['isbn'][7]
# Out:
# '316769177'

# %%
pd.options.display.max_rows
books.head(20)
# Out:
#     id   book_id  best_book_id   work_id  books_count        isbn  \
# 0    1   2767052       2767052   2792775          272   439023483
# 1    2         3             3   4640799          491   439554934
# 2    3     41865         41865   3212258          226   316015849
# 3    4      2657          2657   3275794          487    61120081
# 4    5      4671          4671    245494         1356   743273567
# 5    6  11870085      11870085  16827462          226   525478817
# 6    7      5907          5907   1540236          969   618260307
# 7    8      5107          5107   3036731          360   316769177
# 8    9       960           960   3338963          311  1416524797
# 9   10      1885          1885   3060926         3455   679783261
# 10  11     77203         77203   3295919          283  1594480001
# 11  12  13335037      13335037  13155899          210    62024035
# 12  13      5470          5470    153313          995   451524934
# ...

# %%
ratings.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
book_tags.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tagid_tagname = pd.merge(book_tags,tags, how='left',on = 'tag_id')
tagid_tagname.head(10)
# Out:
#    goodreads_book_id  tag_id   count           tag_name
# 0                  1   30574  167697            to-read
# 1                  1   11305   37174            fantasy
# 2                  1   11557   34173          favorites
# 3                  1    8717   12986  currently-reading
# 4                  1   33114   12716        young-adult
# 5                  1   11743    9954            fiction
# 6                  1   14017    7169       harry-potter
# 7                  1    5207    6221        books-i-own
# 8                  1   22743    4974              owned
# 9                  1   32989    4364                 ya

# %%
tags.tail()
# Out:
#        tag_id    tag_name
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ
